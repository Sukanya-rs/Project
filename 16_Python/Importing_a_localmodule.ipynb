# %%
# %cd /content/sample_data/
# Out:
# /content/sample_data

# %%
# !mkdir -p package
# %cd package
# !mkdir -p file1
# Out:
# /content/sample_data/package

# %%
# %cd /content/sample_data/package/file1
# Out:
# /content/sample_data/package/file1

# %%
# %%writefile /content/sample_data/package/file1/module1.py

def add(x,y):
  a = x+y
  return print(a)

add(2,3)
# Out:
# Writing /content/sample_data/package/file1/module1.py

# %%
# %cd /content/sample_data/
# Out:
# /content/sample_data

# %%
from package import add
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-aa9f0c343e03> in <module>()
# ----> 1 from package import add
#
# ImportError: cannot import name 'add' from 'package' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/sample_data/package/
# Out:
# /content/sample_data/package

# %%
# %%writefile /content/sample_data/package/__init__.py
def func():
  pass
# Out:
# Overwriting /content/sample_data/package/__init__.py

# %%
# %cd /content/sample_data/
# Out:
# /content/sample_data

# %%
from package import add
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-0c108fe76bda> in <module>()
# ----> 1 from package import add
#
# ImportError: cannot import name 'add' from 'package' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys

sys.path.append('/content/sample_data/package/')

# %%
# %cd /content/sample_data/package
# Out:
# /content/sample_data/package

# %%
from package import add
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-aa9f0c343e03> in <module>()
# ----> 1 from package import add
#
# ImportError: cannot import name 'add' from 'package' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/drive/MyDrive/AI_Privacy_Security_Researcher_Developer/Git/Project/11_PySyft_Codebase/
# Out:
# /content/drive/MyDrive/AI_Privacy_Security_Researcher_Developer/Git/Project/11_PySyft_Codebase

# %%
import sys

sys.path.append('/content/drive/MyDrive/AI_Privacy_Security_Researcher_Developer/Git/Project/11_PySyft_Codebase/PySyft/packages/syft/src/')

# %%
import autodp
autodp.PhiTensor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-ff4407e6799a> in <module>()
#       1 import autodp
# ----> 2 autodp.PhiTensor
#
# AttributeError: module 'autodp' has no attribute 'PhiTensor'

# %%
from syft.core.tensor.adp.phi_tensor import PhiTensor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-237b0a9af209> in <module>()
# ----> 1 from syft.core.tensor.adp.phi_tensor import PhiTensor
#
# /content/drive/MyDrive/AI_Privacy_Security_Researcher_Developer/Git/Project/11_PySyft_Codebase/PySyft/packages/syft/src/syft/core/tensor/__init__.py in <module>()
#       3
#       4 # relative
# ----> 5 from . import functions  # noqa: 401
#       6 from ...ast import add_classes
#       7 from ...ast import add_methods
#
# /content/drive/MyDrive/AI_Privacy_Security_Researcher_Developer/Git/Project/11_PySyft_Codebase/PySyft/packages/syft/src/syft/core/tensor/functions.py in <module>()
#      10
#      11 # relative
# ---> 12 from .tensor import Tensor
#      13 from .util import implements
#      14 from .util import inputs2child
#
# ...

# %%
import __future__
print(__future__.all_feature_names)
# Out:
# ['nested_scopes', 'generators', 'division', 'absolute_import', 'with_statement', 'print_function', 'unicode_literals', 'barry_as_FLUFL', 'generator_stop', 'annotations']

# %%
from __future__ import annotations
class A:
    def f(self) -> A:
        pass

# %%
import operator

# %%
from ...import lib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-b5eb87130a69> in <module>()
# ----> 1 from ...import lib
#
# ImportError: attempted relative import with no known parent package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
